# %%
from numpy import loadtxt

# %%
# load the dataset
dataset = loadtxt('C:\\Users\\WIN\\Desktop\\Data Science labs\\Data\\pima-indians-diabetes.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %%
conda install theano
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\WIN\anaconda3
#
#   added / updated specs:
#     - theano
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.9.0                |           py38_0         2.9 MB
#     libgpuarray-0.7.6          |       hfa6e2cd_0         234 KB
#     libpython-2.1              |           py38_0          49 KB
#     m2w64-binutils-2.25.1      |                5        44.3 MB
#     m2w64-bzip2-1.0.6          |                6         100 KB
#     m2w64-crt-git-5.0.0.4636.2595836|                2         3.4 MB
#     m2w64-gcc-5.3.0            |                6        41.1 MB
#     m2w64-gcc-ada-5.3.0        |                6        33.5 MB
#     m2w64-gcc-fortran-5.3.0    |                6        10.3 MB
#     m2w64-gcc-objc-5.3.0       |                6        15.1 MB
#     m2w64-headers-git-5.0.0.4636.c0ad18a|                2         5.6 MB
#     m2w64-isl-0.16.1           |                2         655 KB
#     m2w64-libiconv-1.14        |                6         1.5 MB
#     m2w64-libmangle-git-5.0.0.4509.2e5a9a2|                2          21 KB
#     m2w64-make-4.1.2351.a80a8b8|                2         116 KB
#     m2w64-mpc-1.0.3            |                3          70 KB
#     m2w64-mpfr-3.1.4           |                4         293 KB
#     m2w64-pkg-config-0.29.1    |                2         469 KB
#     m2w64-toolchain-5.3.0      |                7           2 KB
#     m2w64-tools-git-5.0.0.4592.90b8472|                2         314 KB
#     m2w64-windows-default-manifest-6.4|                3           3 KB
#     m2w64-winpthreads-git-5.0.0.4634.697f757|                2          45 KB
#     m2w64-zlib-1.2.8           |               10         197 KB
#     mako-1.1.3                 |             py_0          62 KB
#     pygpu-0.7.6                |   py38h2a96729_0         468 KB
#     theano-1.0.4               |           py38_0         3.2 MB
#     ------------------------------------------------------------
#                                            Total:       164.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   libgpuarray        pkgs/main/win-64::libgpuarray-0.7.6-hfa6e2cd_0
#   libpython          pkgs/main/win-64::libpython-2.1-py38_0
#   m2w64-binutils     pkgs/msys2/win-64::m2w64-binutils-2.25.1-5
#   m2w64-bzip2        pkgs/msys2/win-64::m2w64-bzip2-1.0.6-6
#   m2w64-crt-git      pkgs/msys2/win-64::m2w64-crt-git-5.0.0.4636.2595836-2
#   m2w64-gcc          pkgs/msys2/win-64::m2w64-gcc-5.3.0-6
#   m2w64-gcc-ada      pkgs/msys2/win-64::m2w64-gcc-ada-5.3.0-6
#   m2w64-gcc-fortran  pkgs/msys2/win-64::m2w64-gcc-fortran-5.3.0-6
#   m2w64-gcc-objc     pkgs/msys2/win-64::m2w64-gcc-objc-5.3.0-6
#   m2w64-headers-git  pkgs/msys2/win-64::m2w64-headers-git-5.0.0.4636.c0ad18a-2
#   m2w64-isl          pkgs/msys2/win-64::m2w64-isl-0.16.1-2
#   m2w64-libiconv     pkgs/msys2/win-64::m2w64-libiconv-1.14-6
#   m2w64-libmangle-g~ pkgs/msys2/win-64::m2w64-libmangle-git-5.0.0.4509.2e5a9a2-2
#   m2w64-make         pkgs/msys2/win-64::m2w64-make-4.1.2351.a80a8b8-2
#   m2w64-mpc          pkgs/msys2/win-64::m2w64-mpc-1.0.3-3
#   m2w64-mpfr         pkgs/msys2/win-64::m2w64-mpfr-3.1.4-4
#   m2w64-pkg-config   pkgs/msys2/win-64::m2w64-pkg-config-0.29.1-2
#   m2w64-toolchain    pkgs/msys2/win-64::m2w64-toolchain-5.3.0-7
#   m2w64-tools-git    pkgs/msys2/win-64::m2w64-tools-git-5.0.0.4592.90b8472-2
#   m2w64-windows-def~ pkgs/msys2/win-64::m2w64-windows-default-manifest-6.4-3
#   m2w64-winpthreads~ pkgs/msys2/win-64::m2w64-winpthreads-git-5.0.0.4634.697f757-2
#   m2w64-zlib         pkgs/msys2/win-64::m2w64-zlib-1.2.8-10
#   mako               pkgs/main/noarch::mako-1.1.3-py_0
#   pygpu              pkgs/main/win-64::pygpu-0.7.6-py38h2a96729_0
#   theano             pkgs/main/win-64::theano-1.0.4-py38_0
#
# The following packages will be UPDATED:
#
#   conda              conda-forge::conda-4.8.5-py38h9bdc248~ --> pkgs/main::conda-4.9.0-py38_0
#
#
#
# Downloading and Extracting Packages
#
# libgpuarray-0.7.6    | 234 KB    |            |   0%
# libgpuarray-0.7.6    | 234 KB    | 6          |   7%
# libgpuarray-0.7.6    | 234 KB    | ##7        |  27%
# libgpuarray-0.7.6    | 234 KB    | ######8    |  69%
# libgpuarray-0.7.6    | 234 KB    | ########## | 100%
# libgpuarray-0.7.6    | 234 KB    | ########## | 100%
#
# mako-1.1.3           | 62 KB     |            |   0%
# mako-1.1.3           | 62 KB     | ##5        |  26%
# mako-1.1.3           | 62 KB     | ########## | 100%
# mako-1.1.3           | 62 KB     | ########## | 100%
#
# m2w64-mpfr-3.1.4     | 293 KB    |            |   0%
# m2w64-mpfr-3.1.4     | 293 KB    | ########## | 100%
# m2w64-mpfr-3.1.4     | 293 KB    | ########## | 100%
#
# m2w64-zlib-1.2.8     | 197 KB    |            |   0%
# m2w64-zlib-1.2.8     | 197 KB    | ########## | 100%
# m2w64-zlib-1.2.8     | 197 KB    | ########## | 100%
#
# m2w64-bzip2-1.0.6    | 100 KB    |            |   0%
# m2w64-bzip2-1.0.6    | 100 KB    | ########## | 100%
# m2w64-bzip2-1.0.6    | 100 KB    | ########## | 100%
#
# m2w64-binutils-2.25. | 44.3 MB   |            |   0%
# m2w64-binutils-2.25. | 44.3 MB   |            |   1%
# m2w64-binutils-2.25. | 44.3 MB   | 1          |   2%
# m2w64-binutils-2.25. | 44.3 MB   | 2          |   2%
# m2w64-binutils-2.25. | 44.3 MB   | 3          |   3%
# m2w64-binutils-2.25. | 44.3 MB   | 4          |   4%
# m2w64-binutils-2.25. | 44.3 MB   | 5          |   5%
# m2w64-binutils-2.25. | 44.3 MB   | 5          |   6%
# m2w64-binutils-2.25. | 44.3 MB   | 6          |   7%
# m2w64-binutils-2.25. | 44.3 MB   | 7          |   8%
# m2w64-binutils-2.25. | 44.3 MB   | 8          |   9%
# m2w64-binutils-2.25. | 44.3 MB   | 9          |   9%
# m2w64-binutils-2.25. | 44.3 MB   | #          |  10%
# m2w64-binutils-2.25. | 44.3 MB   | #1         |  11%
# m2w64-binutils-2.25. | 44.3 MB   | #2         |  12%
# m2w64-binutils-2.25. | 44.3 MB   | #3         |  13%
# m2w64-binutils-2.25. | 44.3 MB   | #4         |  14%
# m2w64-binutils-2.25. | 44.3 MB   | #4         |  15%
# m2w64-binutils-2.25. | 44.3 MB   | #5         |  16%
# m2w64-binutils-2.25. | 44.3 MB   | #6         |  17%
# m2w64-binutils-2.25. | 44.3 MB   | #7         |  18%
# m2w64-binutils-2.25. | 44.3 MB   | #8         |  18%
# m2w64-binutils-2.25. | 44.3 MB   | #9         |  19%
# m2w64-binutils-2.25. | 44.3 MB   | ##         |  20%
# m2w64-binutils-2.25. | 44.3 MB   | ##1        |  21%
# m2w64-binutils-2.25. | 44.3 MB   | ##2        |  22%
# m2w64-binutils-2.25. | 44.3 MB   | ##2        |  23%
# m2w64-binutils-2.25. | 44.3 MB   | ##3        |  24%
# m2w64-binutils-2.25. | 44.3 MB   | ##4        |  25%
# m2w64-binutils-2.25. | 44.3 MB   | ##5        |  26%
# m2w64-binutils-2.25. | 44.3 MB   | ##6        |  26%
# m2w64-binutils-2.25. | 44.3 MB   | ##7        |  27%
# m2w64-binutils-2.25. | 44.3 MB   | ##8        |  28%
# m2w64-binutils-2.25. | 44.3 MB   | ##9        |  29%
# m2w64-binutils-2.25. | 44.3 MB   | ###        |  30%
# m2w64-binutils-2.25. | 44.3 MB   | ###1       |  31%
# m2w64-binutils-2.25. | 44.3 MB   | ###1       |  32%
# m2w64-binutils-2.25. | 44.3 MB   | ###2       |  33%
# m2w64-binutils-2.25. | 44.3 MB   | ###3       |  34%
# m2w64-binutils-2.25. | 44.3 MB   | ###4       |  35%
# m2w64-binutils-2.25. | 44.3 MB   | ###5       |  35%
# m2w64-binutils-2.25. | 44.3 MB   | ###6       |  36%
# m2w64-binutils-2.25. | 44.3 MB   | ###7       |  37%
# m2w64-binutils-2.25. | 44.3 MB   | ###8       |  38%
# m2w64-binutils-2.25. | 44.3 MB   | ###9       |  39%
# m2w64-binutils-2.25. | 44.3 MB   | ###9       |  40%
# m2w64-binutils-2.25. | 44.3 MB   | ####       |  41%
# m2w64-binutils-2.25. | 44.3 MB   | ####1      |  42%
# m2w64-binutils-2.25. | 44.3 MB   | ####2      |  43%
# m2w64-binutils-2.25. | 44.3 MB   | ####3      |  43%
# m2w64-binutils-2.25. | 44.3 MB   | ####4      |  44%
# m2w64-binutils-2.25. | 44.3 MB   | ####5      |  45%
# m2w64-binutils-2.25. | 44.3 MB   | ####6      |  46%
# m2w64-binutils-2.25. | 44.3 MB   | ####7      |  47%
# m2w64-binutils-2.25. | 44.3 MB   | ####7      |  48%
# m2w64-binutils-2.25. | 44.3 MB   | ####8      |  49%
# m2w64-binutils-2.25. | 44.3 MB   | ####9      |  50%
# m2w64-binutils-2.25. | 44.3 MB   | #####      |  51%
# Note: you may need to restart the kernel to use updated packages.
# m2w64-binutils-2.25. | 44.3 MB   | #####1     |  52%
# m2w64-binutils-2.25. | 44.3 MB   | #####2     |  52%
# m2w64-binutils-2.25. | 44.3 MB   | #####3     |  53%
# m2w64-binutils-2.25. | 44.3 MB   | #####4     |  54%
# m2w64-binutils-2.25. | 44.3 MB   | #####5     |  55%
# m2w64-binutils-2.25. | 44.3 MB   | #####5     |  56%
# m2w64-binutils-2.25. | 44.3 MB   | #####6     |  57%
# m2w64-binutils-2.25. | 44.3 MB   | #####7     |  58%
# m2w64-binutils-2.25. | 44.3 MB   | #####8     |  59%
# m2w64-binutils-2.25. | 44.3 MB   | #####9     |  59%
# m2w64-binutils-2.25. | 44.3 MB   | ######     |  60%
# m2w64-binutils-2.25. | 44.3 MB   | ######1    |  61%
# m2w64-binutils-2.25. | 44.3 MB   | ######2    |  62%
# m2w64-binutils-2.25. | 44.3 MB   | ######2    |  63%
# m2w64-binutils-2.25. | 44.3 MB   | ######3    |  64%
# m2w64-binutils-2.25. | 44.3 MB   | ######4    |  65%
# m2w64-binutils-2.25. | 44.3 MB   | ######5    |  66%
# m2w64-binutils-2.25. | 44.3 MB   | ######6    |  67%
# m2w64-binutils-2.25. | 44.3 MB   | ######7    |  68%
# m2w64-binutils-2.25. | 44.3 MB   | ######8    |  68%
# m2w64-binutils-2.25. | 44.3 MB   | ######9    |  69%
# m2w64-binutils-2.25. | 44.3 MB   | #######    |  70%
# m2w64-binutils-2.25. | 44.3 MB   | #######1   |  71%
# m2w64-binutils-2.25. | 44.3 MB   | #######1   |  72%
# m2w64-binutils-2.25. | 44.3 MB   | #######2   |  73%
# m2w64-binutils-2.25. | 44.3 MB   | #######3   |  74%
# m2w64-binutils-2.25. | 44.3 MB   | #######4   |  75%
# m2w64-binutils-2.25. | 44.3 MB   | #######5   |  75%
# m2w64-binutils-2.25. | 44.3 MB   | #######6   |  76%
# m2w64-binutils-2.25. | 44.3 MB   | #######7   |  77%
# m2w64-binutils-2.25. | 44.3 MB   | #######8   |  78%
# m2w64-binutils-2.25. | 44.3 MB   | #######9   |  79%
# m2w64-binutils-2.25. | 44.3 MB   | #######9   |  80%
# m2w64-binutils-2.25. | 44.3 MB   | ########   |  81%
# m2w64-binutils-2.25. | 44.3 MB   | ########1  |  82%
# m2w64-binutils-2.25. | 44.3 MB   | ########2  |  82%
# m2w64-binutils-2.25. | 44.3 MB   | ########3  |  83%
# m2w64-binutils-2.25. | 44.3 MB   | ########4  |  84%
# m2w64-binutils-2.25. | 44.3 MB   | ########4  |  85%
# m2w64-binutils-2.25. | 44.3 MB   | ########5  |  86%
# m2w64-binutils-2.25. | 44.3 MB   | ########6  |  87%
# m2w64-binutils-2.25. | 44.3 MB   | ########7  |  88%
# m2w64-binutils-2.25. | 44.3 MB   | ########8  |  89%
# m2w64-binutils-2.25. | 44.3 MB   | ########9  |  89%
# m2w64-binutils-2.25. | 44.3 MB   | #########  |  90%
# m2w64-binutils-2.25. | 44.3 MB   | #########1 |  91%
# m2w64-binutils-2.25. | 44.3 MB   | #########2 |  92%
# m2w64-binutils-2.25. | 44.3 MB   | #########2 |  93%
# m2w64-binutils-2.25. | 44.3 MB   | #########3 |  94%
# m2w64-binutils-2.25. | 44.3 MB   | #########4 |  95%
# m2w64-binutils-2.25. | 44.3 MB   | #########5 |  96%
# m2w64-binutils-2.25. | 44.3 MB   | #########6 |  97%
# m2w64-binutils-2.25. | 44.3 MB   | #########7 |  97%
# m2w64-binutils-2.25. | 44.3 MB   | #########8 |  98%
# m2w64-binutils-2.25. | 44.3 MB   | #########9 |  99%
# m2w64-binutils-2.25. | 44.3 MB   | ########## | 100%
#
# m2w64-winpthreads-gi | 45 KB     |            |   0%
# m2w64-winpthreads-gi | 45 KB     | ########## | 100%
# m2w64-winpthreads-gi | 45 KB     | ########## | 100%
#
# m2w64-gcc-fortran-5. | 10.3 MB   |            |   0%
# m2w64-gcc-fortran-5. | 10.3 MB   | 3          |   3%
# m2w64-gcc-fortran-5. | 10.3 MB   | 6          |   7%
# m2w64-gcc-fortran-5. | 10.3 MB   | #          |  10%
# m2w64-gcc-fortran-5. | 10.3 MB   | #3         |  14%
# m2w64-gcc-fortran-5. | 10.3 MB   | #7         |  17%
# m2w64-gcc-fortran-5. | 10.3 MB   | ##1        |  21%
# m2w64-gcc-fortran-5. | 10.3 MB   | ##5        |  25%
# m2w64-gcc-fortran-5. | 10.3 MB   | ##9        |  29%
# m2w64-gcc-fortran-5. | 10.3 MB   | ###2       |  33%
# m2w64-gcc-fortran-5. | 10.3 MB   | ###6       |  36%
# m2w64-gcc-fortran-5. | 10.3 MB   | ####       |  40%
# m2w64-gcc-fortran-5. | 10.3 MB   | ####4      |  44%
# m2w64-gcc-fortran-5. | 10.3 MB   | ####7      |  48%
# m2w64-gcc-fortran-5. | 10.3 MB   | #####1     |  52%
# m2w64-gcc-fortran-5. | 10.3 MB   | #####5     |  56%
# m2w64-gcc-fortran-5. | 10.3 MB   | #####9     |  60%
# m2w64-gcc-fortran-5. | 10.3 MB   | ######3    |  64%
# m2w64-gcc-fortran-5. | 10.3 MB   | ######7    |  67%
# m2w64-gcc-fortran-5. | 10.3 MB   | #######1   |  71%
# m2w64-gcc-fortran-5. | 10.3 MB   | #######5   |  75%
# m2w64-gcc-fortran-5. | 10.3 MB   | #######9   |  79%
# m2w64-gcc-fortran-5. | 10.3 MB   | ########2  |  83%
# m2w64-gcc-fortran-5. | 10.3 MB   | ########6  |  86%
# m2w64-gcc-fortran-5. | 10.3 MB   | #########  |  90%
# m2w64-gcc-fortran-5. | 10.3 MB   | #########4 |  94%
# m2w64-gcc-fortran-5. | 10.3 MB   | #########8 |  98%
# m2w64-gcc-fortran-5. | 10.3 MB   | ########## | 100%
#
# m2w64-mpc-1.0.3      | 70 KB     |            |   0%
# m2w64-mpc-1.0.3      | 70 KB     | ########## | 100%
#
# m2w64-crt-git-5.0.0. | 3.4 MB    |            |   0%
# m2w64-crt-git-5.0.0. | 3.4 MB    | 9          |   9%
# m2w64-crt-git-5.0.0. | 3.4 MB    | ##         |  21%
# m2w64-crt-git-5.0.0. | 3.4 MB    | ###        |  30%
# m2w64-crt-git-5.0.0. | 3.4 MB    | ####1      |  41%
# m2w64-crt-git-5.0.0. | 3.4 MB    | #####3     |  53%
# m2w64-crt-git-5.0.0. | 3.4 MB    | ######2    |  62%
# m2w64-crt-git-5.0.0. | 3.4 MB    | #######3   |  73%
# m2w64-crt-git-5.0.0. | 3.4 MB    | ########5  |  85%
# m2w64-crt-git-5.0.0. | 3.4 MB    | #########6 |  96%
# m2w64-crt-git-5.0.0. | 3.4 MB    | ########## | 100%
#
# m2w64-libmangle-git- | 21 KB     |            |   0%
# m2w64-libmangle-git- | 21 KB     | ########## | 100%
#
# m2w64-gcc-ada-5.3.0  | 33.5 MB   |            |   0%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   |            |   1%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | 1          |   2%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | 3          |   3%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | 4          |   4%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | 5          |   5%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | 6          |   6%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | 7          |   8%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | 8          |   9%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #          |  10%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #1         |  11%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #2         |  12%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #3         |  13%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #4         |  15%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #5         |  16%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #6         |  17%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #8         |  18%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #9         |  19%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ##         |  20%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ##1        |  22%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ##2        |  23%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ##3        |  24%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ##5        |  25%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ##6        |  26%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ##7        |  27%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ##8        |  29%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ##9        |  30%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ###        |  31%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ###2       |  32%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ###3       |  33%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ###4       |  35%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ###5       |  36%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ###6       |  37%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ###8       |  38%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ###9       |  39%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ####       |  40%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ####1      |  41%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ####2      |  43%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ####3      |  44%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ####4      |  45%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ####6      |  46%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ####7      |  47%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ####8      |  48%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ####9      |  50%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #####      |  51%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #####1     |  52%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #####3     |  53%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #####4     |  54%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #####5     |  55%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #####6     |  57%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #####7     |  58%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #####9     |  59%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ######     |  60%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ######1    |  61%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ######2    |  63%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ######3    |  64%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ######4    |  65%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ######6    |  66%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ######7    |  67%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ######8    |  68%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ######9    |  70%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #######    |  71%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #######1   |  72%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #######3   |  73%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #######4   |  74%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #######5   |  75%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #######6   |  77%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #######7   |  78%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #######9   |  79%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########   |  80%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########1  |  81%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########2  |  83%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########3  |  84%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########4  |  85%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########6  |  86%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########7  |  87%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########8  |  89%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########9  |  90%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #########1 |  91%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #########2 |  92%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #########3 |  93%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #########4 |  95%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #########5 |  96%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #########6 |  97%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #########8 |  98%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | #########9 |  99%
# m2w64-gcc-ada-5.3.0  | 33.5 MB   | ########## | 100%
#
# theano-1.0.4         | 3.2 MB    |            |   0%
# theano-1.0.4         | 3.2 MB    |            |   0%
# theano-1.0.4         | 3.2 MB    | 3          |   4%
# theano-1.0.4         | 3.2 MB    | 7          |   8%
# theano-1.0.4         | 3.2 MB    | #3         |  13%
# theano-1.0.4         | 3.2 MB    | ##3        |  24%
# theano-1.0.4         | 3.2 MB    | ###3       |  34%
# theano-1.0.4         | 3.2 MB    | ####6      |  47%
# theano-1.0.4         | 3.2 MB    | ######     |  60%
# theano-1.0.4         | 3.2 MB    | #######1   |  72%
# theano-1.0.4         | 3.2 MB    | ########4  |  84%
# theano-1.0.4         | 3.2 MB    | #########6 |  97%
# theano-1.0.4         | 3.2 MB    | ########## | 100%
#
# m2w64-gcc-5.3.0      | 41.1 MB   |            |   0%
# m2w64-gcc-5.3.0      | 41.1 MB   |            |   1%
# m2w64-gcc-5.3.0      | 41.1 MB   | 1          |   2%
# m2w64-gcc-5.3.0      | 41.1 MB   | 2          |   3%
# m2w64-gcc-5.3.0      | 41.1 MB   | 3          |   3%
# m2w64-gcc-5.3.0      | 41.1 MB   | 4          |   4%
# m2w64-gcc-5.3.0      | 41.1 MB   | 5          |   5%
# m2w64-gcc-5.3.0      | 41.1 MB   | 6          |   6%
# m2w64-gcc-5.3.0      | 41.1 MB   | 7          |   7%
# m2w64-gcc-5.3.0      | 41.1 MB   | 8          |   8%
# m2w64-gcc-5.3.0      | 41.1 MB   | 9          |   9%
# m2w64-gcc-5.3.0      | 41.1 MB   | #          |  10%
# m2w64-gcc-5.3.0      | 41.1 MB   | #1         |  11%
# m2w64-gcc-5.3.0      | 41.1 MB   | #2         |  12%
# m2w64-gcc-5.3.0      | 41.1 MB   | #2         |  13%
# m2w64-gcc-5.3.0      | 41.1 MB   | #3         |  14%
# m2w64-gcc-5.3.0      | 41.1 MB   | #4         |  15%
# m2w64-gcc-5.3.0      | 41.1 MB   | #5         |  16%
# m2w64-gcc-5.3.0      | 41.1 MB   | #6         |  17%
# m2w64-gcc-5.3.0      | 41.1 MB   | #7         |  18%
# m2w64-gcc-5.3.0      | 41.1 MB   | #8         |  19%
# m2w64-gcc-5.3.0      | 41.1 MB   | #9         |  20%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##         |  21%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##1        |  22%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##2        |  23%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##3        |  23%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##4        |  24%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##5        |  25%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##6        |  26%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##7        |  27%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##8        |  28%
# m2w64-gcc-5.3.0      | 41.1 MB   | ##9        |  29%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###        |  30%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###1       |  31%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###2       |  32%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###3       |  33%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###4       |  34%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###4       |  35%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###5       |  36%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###6       |  37%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###7       |  38%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###8       |  39%
# m2w64-gcc-5.3.0      | 41.1 MB   | ###9       |  40%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####       |  41%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####1      |  42%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####2      |  43%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####3      |  44%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####4      |  45%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####5      |  46%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####6      |  47%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####7      |  48%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####8      |  48%
# m2w64-gcc-5.3.0      | 41.1 MB   | ####9      |  49%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####      |  50%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####1     |  51%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####2     |  52%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####3     |  53%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####4     |  54%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####5     |  55%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####6     |  56%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####7     |  57%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####8     |  58%
# m2w64-gcc-5.3.0      | 41.1 MB   | #####9     |  59%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######     |  60%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######1    |  61%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######1    |  62%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######2    |  63%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######3    |  64%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######4    |  65%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######5    |  66%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######6    |  67%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######7    |  68%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######8    |  69%
# m2w64-gcc-5.3.0      | 41.1 MB   | ######9    |  70%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######    |  70%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######1   |  71%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######2   |  72%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######3   |  73%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######4   |  74%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######5   |  75%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######5   |  76%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######6   |  77%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######7   |  78%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######8   |  79%
# m2w64-gcc-5.3.0      | 41.1 MB   | #######9   |  80%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########   |  81%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########1  |  82%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########2  |  83%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########3  |  84%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########4  |  85%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########5  |  86%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########6  |  87%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########7  |  87%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########8  |  88%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########9  |  89%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########  |  90%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########1 |  91%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########2 |  92%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########3 |  93%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########4 |  94%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########5 |  95%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########5 |  96%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########6 |  97%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########7 |  98%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########8 |  99%
# m2w64-gcc-5.3.0      | 41.1 MB   | #########9 | 100%
# m2w64-gcc-5.3.0      | 41.1 MB   | ########## | 100%
#
# pygpu-0.7.6          | 468 KB    |            |   0%
# pygpu-0.7.6          | 468 KB    | 3          |   3%
# pygpu-0.7.6          | 468 KB    | ##3        |  24%
# pygpu-0.7.6          | 468 KB    | ####1      |  41%
# pygpu-0.7.6          | 468 KB    | #######1   |  72%
# pygpu-0.7.6          | 468 KB    | ########## | 100%
# pygpu-0.7.6          | 468 KB    | ########## | 100%
#
# m2w64-gcc-objc-5.3.0 | 15.1 MB   |            |   0%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | 1          |   2%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | 4          |   4%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | 6          |   7%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | 9          |   9%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #2         |  12%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #4         |  15%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #7         |  17%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #9         |  20%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ##2        |  22%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ##5        |  25%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ##7        |  28%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ###        |  30%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ###2       |  33%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ###5       |  35%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ###8       |  38%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ####       |  41%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ####3      |  43%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ####5      |  46%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ####8      |  48%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #####      |  51%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #####3     |  54%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #####6     |  56%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #####9     |  59%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ######1    |  62%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ######4    |  64%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ######6    |  67%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ######9    |  70%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #######2   |  72%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #######4   |  75%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #######7   |  78%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ########   |  80%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ########2  |  83%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ########5  |  86%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ########8  |  88%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #########  |  91%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #########3 |  93%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #########5 |  96%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | #########8 |  99%
# m2w64-gcc-objc-5.3.0 | 15.1 MB   | ########## | 100%
#
# libpython-2.1        | 49 KB     |            |   0%
# libpython-2.1        | 49 KB     | ########## | 100%
# libpython-2.1        | 49 KB     | ########## | 100%
#
# conda-4.9.0          | 2.9 MB    |            |   0%
# conda-4.9.0          | 2.9 MB    | #          |  11%
# conda-4.9.0          | 2.9 MB    | ##5        |  26%
# conda-4.9.0          | 2.9 MB    | ###6       |  37%
# conda-4.9.0          | 2.9 MB    | #####      |  51%
# conda-4.9.0          | 2.9 MB    | ######4    |  64%
# conda-4.9.0          | 2.9 MB    | #######8   |  78%
# conda-4.9.0          | 2.9 MB    | #########1 |  92%
# conda-4.9.0          | 2.9 MB    | ########## | 100%
#
# m2w64-libiconv-1.14  | 1.5 MB    |            |   0%
# m2w64-libiconv-1.14  | 1.5 MB    | ##         |  20%
# m2w64-libiconv-1.14  | 1.5 MB    | ####6      |  47%
# m2w64-libiconv-1.14  | 1.5 MB    | #######5   |  76%
# m2w64-libiconv-1.14  | 1.5 MB    | ########## | 100%
# m2w64-libiconv-1.14  | 1.5 MB    | ########## | 100%
#
# m2w64-isl-0.16.1     | 655 KB    |            |   0%
# m2w64-isl-0.16.1     | 655 KB    | ####6      |  46%
# m2w64-isl-0.16.1     | 655 KB    | ########## | 100%
# m2w64-isl-0.16.1     | 655 KB    | ########## | 100%
#
# m2w64-make-4.1.2351. | 116 KB    |            |   0%
# m2w64-make-4.1.2351. | 116 KB    | ########## | 100%
# m2w64-make-4.1.2351. | 116 KB    | ########## | 100%
#
# m2w64-toolchain-5.3. | 2 KB      |            |   0%
# m2w64-toolchain-5.3. | 2 KB      | ########## | 100%
#
# m2w64-windows-defaul | 3 KB      |            |   0%
# m2w64-windows-defaul | 3 KB      | ########## | 100%
#
# m2w64-headers-git-5. | 5.6 MB    |            |   0%
# m2w64-headers-git-5. | 5.6 MB    | 5          |   5%
# m2w64-headers-git-5. | 5.6 MB    | #2         |  13%
# m2w64-headers-git-5. | 5.6 MB    | #9         |  20%
# m2w64-headers-git-5. | 5.6 MB    | ##4        |  25%
# m2w64-headers-git-5. | 5.6 MB    | ###2       |  32%
# m2w64-headers-git-5. | 5.6 MB    | ###9       |  39%
# m2w64-headers-git-5. | 5.6 MB    | ####6      |  47%
# m2w64-headers-git-5. | 5.6 MB    | #####3     |  54%
# m2w64-headers-git-5. | 5.6 MB    | ######     |  60%
# m2w64-headers-git-5. | 5.6 MB    | ######7    |  67%
# m2w64-headers-git-5. | 5.6 MB    | #######4   |  74%
# m2w64-headers-git-5. | 5.6 MB    | ########1  |  81%
# m2w64-headers-git-5. | 5.6 MB    | ########8  |  88%
# m2w64-headers-git-5. | 5.6 MB    | #########5 |  95%
# m2w64-headers-git-5. | 5.6 MB    | ########## | 100%
#
# m2w64-pkg-config-0.2 | 469 KB    |            |   0%
# m2w64-pkg-config-0.2 | 469 KB    | ######8    |  68%
# m2w64-pkg-config-0.2 | 469 KB    | ########## | 100%
# m2w64-pkg-config-0.2 | 469 KB    | ########## | 100%
#
# m2w64-tools-git-5.0. | 314 KB    |            |   0%
# m2w64-tools-git-5.0. | 314 KB    | ########## | 100%
# m2w64-tools-git-5.0. | 314 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\win\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (1.18.5)
# Requirement already satisfied: scipy==1.4.1 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (1.4.1)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (0.10.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in c:\users\win\anaconda3\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: setuptools in c:\users\win\anaconda3\lib\site-packages (from protobuf>=3.9.2->tensorflow) (49.2.0.post20200714)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\win\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.24.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\win\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.3.2)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\win\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\win\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\win\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.22.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\win\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\win\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\win\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\win\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\win\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.25.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\win\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\win\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\win\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\win\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\win\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\win\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\win\anaconda3\lib\site-packages (2.4.3)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy>=1.9.1 in c:\users\win\anaconda3\lib\site-packages (from keras) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in c:\users\win\anaconda3\lib\site-packages (from keras) (1.4.1)
# Requirement already satisfied: pyyaml in c:\users\win\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: h5py in c:\users\win\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: six in c:\users\win\anaconda3\lib\site-packages (from h5py->keras) (1.15.0)

# %%
# theano
import theano
print('theano: %s' % theano.__version__)
# Out:
# theano: 1.0.4

# %%
# first neural network with keras tutorial
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
# load the dataset
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      63   try:
# ---> 64     from tensorflow.python._pywrap_tensorflow_internal import *
#      65   # This try catch logic is because there is no bazel equivalent for py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ~\anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#
# ~\anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      39
# ---> 40 from tensorflow.python.eager import context
#      41
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py in <module>
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
# ---> 35 from tensorflow.python import pywrap_tfe
#      36 from tensorflow.python import tf2
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tfe.py in <module>
#      27 # pylint: disable=invalid-import-order,g-bad-import-order, wildcard-import, unused-import
# ---> 28 from tensorflow.python import pywrap_tensorflow
#      29 from tensorflow.python._pywrap_tfe import *
#
# ~\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in <module>
#      82 above this error message when asking for help.""" % traceback.format_exc()
# ---> 83   raise ImportError(msg)
#      84
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\WIN\anaconda3\lib\site-packages\tensorflow\python\pywrap_tensorflow.py", line 64, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
#
# See https://www.tensorflow.org/install/errors
#
# for some common reasons and solutions.  Include the entire stack trace
# above this error message when asking for help.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-a53a1cc01b99> in <module>
#       1 # first neural network with keras tutorial
#       2 from numpy import loadtxt
# ----> 3 from keras.models import Sequential
#       4 from keras.layers import Dense
#       5 # load the dataset
#
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#       3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
# ----> 5     raise ImportError(
#       6         'Keras requires TensorFlow 2.2 or higher. '
#       7         'Install TensorFlow via `pip install tensorflow`')
#
# ImportError: Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`
